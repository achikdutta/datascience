# %%
#Import the test data file


import pandas as pd
import numpy as np
import warnings as warnings

warnings.filterwarnings('ignore')
traindf = pd.read_csv('/Users/achintyadutta/Documents/UPGRAD/Kaggle1/train.csv',sep=',',encoding='ISO-8859-1')
testdf=pd.read_csv('/Users/achintyadutta/Documents/UPGRAD/Kaggle1/test.csv',sep=',',encoding='ISO-8859-1')
survived = pd.read_csv('/Users/achintyadutta/Documents/UPGRAD/Kaggle1/gender_submission.csv',sep=',',encoding='ISO-8859-1')

survived.info() # 418 entries
testdf.info() # 418 entries
traindf
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
# PassengerId    418 non-null int64
# Survived       418 non-null int64
# dtypes: int64(2)
# memory usage: 6.6 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# ...

# %%
#Check the Nulls
testdf.isna().sum()

#Initial - age = 86, Cabin = 327 and Fare =1
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#Get the male passengers
testdf.groupby('Sex').Age.mean()

#female- 30.272362
#male - 30.272732
# Out:
# Sex
# female    30.272362
# male      30.272732
# Name: Age, dtype: float64

# %%
traindf.isna().sum()
testdf.loc[testdf['PassengerId']==1272]
# Out:
#      PassengerId  Pclass                   Name   Sex  Age  SibSp  Parch  \
# 380         1272       3  O'Connor, Mr. Patrick  male  NaN      0      0
#
#      Ticket  Fare Cabin Embarked  Survived
# 380  366713  7.75   NaN        Q       NaN

# %%
traindf.groupby('Sex').Age.mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
#Check the Male passengers and impute with average age for NaNs
testdf.loc[(testdf.Age.isna()),'Age'] = 30.27
traindf.loc[(traindf.Age.isna()) & (traindf.Sex == 'male'),'Age']=30.73
traindf.loc[(traindf.Age.isna()) & (traindf.Sex == 'female'),'Age']=27.92

# %%
traindf.isna().sum()
traindf.groupby(['Survived','Sex']).PassengerId.count() 
#Female survival rate is more than Male 233/109

traindf.loc[traindf.Sex=='female'].groupby('Survived').PassengerId.count()/traindf.groupby('Survived').PassengerId.count()*100
traindf.loc[traindf.Sex=='male'].groupby('Survived').PassengerId.count()/traindf.groupby('Survived').PassengerId.count()*100


#Female Survival percentage is 68% which is way above male 32%

# So from here we know we can have a decision tree based on female passengers 
#- this will be our root
# Thus we compute the other parameters to reach our goal.
# Here we will use manual calculations as of now based on what we have learned so far

# Test param 1 - How many survived from cabin class, middle class and lower class

traindf.loc[(traindf.Sex=='female') & (traindf.Survived == 1)].groupby('Pclass').PassengerId.count()/len(traindf.loc[(traindf.Sex=='female') & (traindf.Survived == 1)])*100
#Pclass
#1    39.055794
#2    30.042918
#3    30.901288

len(traindf.loc[(traindf.Sex=='female') & (traindf.Survived == 1) & ((traindf.Parch > 0) | (traindf.SibSp > 0)) & (traindf.Pclass == 3)])/len(traindf.loc[(traindf.Sex=='female') & (traindf.Survived == 1)])*100

# From above we see if a female passenger is accompanied by Siblings/Parents 
# the Survival % goes up to 57.5%
final_traindf = traindf.loc[(traindf.Sex=='female') & (traindf.Survived == 1) & ((traindf.Parch > 0) | (traindf.SibSp > 0))]

# We can check for the test data here and avoid overfitting as we have already considered 3 columns


len(traindf.loc[(traindf.Sex=='female') & (traindf.Survived == 1) & (traindf.Pclass == 3)])/len(traindf.loc[(traindf.Sex=='female') & (traindf.Survived == 1)])*100
# Out:
# 30.90128755364807

# %%
len(traindf.loc[(traindf.Sex=='female') & (traindf.Survived == 1) & ((traindf.Parch > 0) | (traindf.SibSp > 0))])/len(traindf.loc[(traindf.Sex=='female') & (traindf.Survived == 1)])*100
# Out:
# 57.5107296137339

# %%
#Check the test df
testdf.isna().sum()

testdf.loc[(testdf.Sex=='female') & ((testdf.Parch > 0) | (testdf.SibSp > 0)),'Survived'] = 1
female_test_df=testdf

#female_test_df = pd.merge(survived,final_traindf,how='inner',left_on=['PassengerId'],right_on=['PassengerId'])
female_test_df
female_test_df.loc[female_test_df.PassengerId == 893]
survived.loc[survived.PassengerId==893]
#survived_df = pd.merge(female_test_df,survived,how='outer',left_on=['PassengerId'],right_on=['PassengerId'])
#survived.groupby('Survived').PassengerId.count() # 0-266, 1- 152



#len(survived_df.loc[survived_df.Survived_x==1])/len(survived.loc[survived.Survived==1])*100
# Out:
#    PassengerId  Survived
# 1          893         1

# %%
testdf
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
female_test_df=testdf

# %%
female_test_df=female_test_df.loc[female_test_df.Sex=='female']

# %%
female_test_df1 = female_test_df

# %%
female_test_df1.loc[female_test_df1.Pclass ==1,'Survived'] =1

# %%
female_test_df1
# Out:
#      PassengerId  Pclass                                               Name  \
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6            898       3                               Connolly, Miss. Kate
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 15           907       2      del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 18           910       3                       Ilmakangas, Miss. Ida Livija
# 19           911       3              Assaf Khalil, Mrs. Mariana (Miriam")"
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# ...

# %%
female_final = pd.merge(survived,female_test_df,how='inner',left_on=['PassengerId'],right_on=['PassengerId'])

# %%
female_final1 = pd.merge(survived,female_test_df1,how='inner',left_on=['PassengerId'],right_on=['PassengerId'])

# %%
female_final
# Out:
#      PassengerId  Survived_x  Pclass  \
# 0            893           1       3
# 1            896           1       3
# 2            898           1       3
# 3            900           1       3
# 4            904           1       1
# 5            906           1       1
# 6            907           1       2
# 7            910           1       3
# 8            911           1       3
# 9            914           1       1
# 10           916           1       1
# 11           918           1       1
# 12           924           1       3
# 13           925           1       3
# 14           928           1       3
# 15           929           1       3
# 16           935           1       2
# 17           936           1       1
# 18           940           1       1
# 19           941           1       3
# 20           944           1       2
# 21           945           1       1
# 22           951           1       1
# 23           955           1       3
# ...

# %%
len(female_final.loc[(female_final.Survived_y==1.0) & (female_final.Survived_x==1.0)])/len(female_final)*100
# Out:
# 55.26315789473685

# %%
testdf.loc[(testdf.Sex=='female') & (testdf.Survived.isna()) & (testdf.Pclass == 1)]
# Out:
#      PassengerId  Pclass                                               Name  \
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 48           940       1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 59           951       1                        Chaudanson, Miss. Victorine
# 74           966       1                               Geiger, Miss. Amalie
# 112         1004       1                           Evans, Miss. Edith Corse
# 141         1033       1                               Daniels, Miss. Sarah
# 156         1048       1                                  Bird, Miss. Ellen
# 168         1060       1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 208         1100       1                      Rosenbaum, Miss. Edith Louise
# 224         1116       1   Candee, Mrs. Edward (Helen Churchill Hungerford)
# 231         1123       1                           Willard, Miss. Constance
# ...

# %%
traindf.loc[traindf.Sex=='male'].groupby('Survived').PassengerId.count()/traindf.groupby('Survived').PassengerId.count()*100
# Out:
# Survived
# 0    85.245902
# 1    31.871345
# Name: PassengerId, dtype: float64

# %%
traindf.loc[traindf.Age.isna(),'Age']=traindf.loc[(traindf.Sex=='male') & (traindf.Survived == 1)].Age.mean()

# %%
len(traindf.loc[(traindf.Sex=='male') & (traindf.Survived == 1) & ((traindf.Age >=1) & (traindf.Age<=35))])/len(traindf.loc[(traindf.Sex=='male') & (traindf.Survived == 1)])*100

# Percentage of the male survival - almost 72%
# Out:
# 71.55963302752293

# %%
maledf = testdf
maledf
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
#maledf.loc[maledf.Survived.isna(),'Survived'] = 0
maledf.loc[(maledf.Sex=='male') & ((traindf.Age >=1) & (traindf.Age<=35)),'Survived'] = 1

# %%
maledf
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
maledf.loc[maledf.Survived.isna(),'Survived'] =0

# %%
maledf
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
male_final = pd.merge(survived,maledf,how='inner',left_on=['PassengerId'],right_on=['PassengerId'])

# %%
male_final
# Out:
#      PassengerId  Survived_x  Pclass  \
# 0            892           0       3
# 1            893           1       3
# 2            894           0       2
# 3            895           0       3
# 4            896           1       3
# 5            897           0       3
# 6            898           1       3
# 7            899           0       2
# 8            900           1       3
# 9            901           0       3
# 10           902           0       3
# 11           903           0       1
# 12           904           1       1
# 13           905           0       2
# 14           906           1       1
# 15           907           1       2
# 16           908           0       2
# 17           909           0       3
# 18           910           1       3
# 19           911           1       3
# 20           912           0       1
# 21           913           0       3
# 22           914           1       1
# 23           915           0       1
# ...

# %%
len(male_final.loc[(male_final.Survived_y==1.0) & (male_final.Survived_x==1)])/len(male_final)*100
# Out:
# 20.095693779904305

# %%
testdf.loc[testdf.Sex=='female'].count()
male_final
# Out:
#      PassengerId  Survived_x  Pclass  \
# 0            892           0       3
# 1            893           1       3
# 2            894           0       2
# 3            895           0       3
# 4            896           1       3
# 5            897           0       3
# 6            898           1       3
# 7            899           0       2
# 8            900           1       3
# 9            901           0       3
# 10           902           0       3
# 11           903           0       1
# 12           904           1       1
# 13           905           0       2
# 14           906           1       1
# 15           907           1       2
# 16           908           0       2
# 17           909           0       3
# 18           910           1       3
# 19           911           1       3
# 20           912           0       1
# 21           913           0       3
# 22           914           1       1
# 23           915           0       1
# ...

# %%
result = female_final.append(male_final)

# %%
final_result=result[['PassengerId','Survived_y']]

# %%
final_result=final_result.rename(index=str,columns={"Survived_y":"Survived"})

# %%
final_result.loc[final_result.Survived.isna(),'Survived'] = 0

# %%
final_result.Survived=final_result.Survived.round(0).astype(int)

# %%
#final_result.to_csv('/Users/achintyadutta/Documents/UPGRAD/Kaggle1/final_result.csv',sep=',')

# %%
final_result=male_final[['PassengerId','Survived_y']]

# %%
final_result=final_result.rename(index=str,columns={"Survived_y":"Survived"})

# %%
final_result.Survived=final_result.Survived.round(0).astype(int)

# %%
final_result.to_csv('/Users/achintyadutta/Documents/UPGRAD/Kaggle1/final_result.csv',sep=',')
